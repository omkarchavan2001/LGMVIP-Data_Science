# %% [markdown]
# #                  Let's Grow More - Data Science Intern

# %% [markdown]
# ### Name - Omkar Chavan

# %% [markdown]
# ##

# %% [markdown]
# ## Task - 1 : Iris Flowers Classification ML Project :

# %% [markdown]
# ### Dataset :- http://archive.ics.uci.edu/ml/datasets/Iris

# %% [markdown]
# ##

# %% [markdown]
# # Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# # Importing dataset

# %%
iris = pd.read_csv('iris_data.data')

# %% [markdown]
# # Understanding the Dataset

# %%
print(iris)
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
iris
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
type(iris)
# Out:
# pandas.core.frame.DataFrame

# %%
# copy iris data to dataframe so we can change it and restore it

df = iris.copy()

# %%
# let change the column first so we can read it correctly
df.columns
# Out:
# Index(['5.1', '3.5', '1.4', '0.2', 'Iris-setosa'], dtype='object')

# %%
# changing columns
df.columns = ['sl','sw','pl','pw','flower_type']

# %%
# looking few row of dataframe
df.head()
# Out:
#     sl   sw   pl   pw  flower_type
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
df.tail()
# Out:
#       sl   sw   pl   pw     flower_type
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica

# %%
# checking shape of data i.e columns, rows
df.shape
# Out:
# (149, 5)

# %%
# checking datatype of columns
df.dtypes
# Out:
# sl             float64
# sw             float64
# pl             float64
# pw             float64
# flower_type     object
# dtype: object

# %%
# describing data
df.describe()
# Out:
#                sl          sw          pl          pw
# count  149.000000  149.000000  149.000000  149.000000
# mean     5.848322    3.051007    3.774497    1.205369
# std      0.828594    0.433499    1.759651    0.761292
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
# seeing particular column
df.sl
# Out:
# 0      4.9
# 1      4.7
# 2      4.6
# 3      5.0
# 4      5.4
#       ...
# 144    6.7
# 145    6.3
# 146    6.5
# 147    6.2
# 148    5.9
# Name: sl, Length: 149, dtype: float64

# %%
# another method to access particular column
df['sl']
# Out:
# 0      4.9
# 1      4.7
# 2      4.6
# 3      5.0
# 4      5.4
#       ...
# 144    6.7
# 145    6.3
# 146    6.5
# 147    6.2
# 148    5.9
# Name: sl, Length: 149, dtype: float64

# %%
# checking null values in data
df.isnull()
# gives true for null value
# Out:
#         sl     sw     pl     pw  flower_type
# 0    False  False  False  False        False
# 1    False  False  False  False        False
# 2    False  False  False  False        False
# 3    False  False  False  False        False
# 4    False  False  False  False        False
# ..     ...    ...    ...    ...          ...
# 144  False  False  False  False        False
# 145  False  False  False  False        False
# 146  False  False  False  False        False
# 147  False  False  False  False        False
# 148  False  False  False  False        False
#
# [149 rows x 5 columns]

# %%
# checking column wise null value
df.isnull().sum()
# Out:
# sl             0
# sw             0
# pl             0
# pw             0
# flower_type    0
# dtype: int64

# %%
# Accessing particular data inbetween

df.iloc[1:4,2:6]
# Out:
#     pl   pw  flower_type
# 1  1.3  0.2  Iris-setosa
# 2  1.5  0.2  Iris-setosa
# 3  1.4  0.2  Iris-setosa

# %%
df.iloc[50:70,:]
# Out:
#      sl   sw   pl   pw      flower_type
# 50  6.4  3.2  4.5  1.5  Iris-versicolor
# 51  6.9  3.1  4.9  1.5  Iris-versicolor
# 52  5.5  2.3  4.0  1.3  Iris-versicolor
# 53  6.5  2.8  4.6  1.5  Iris-versicolor
# 54  5.7  2.8  4.5  1.3  Iris-versicolor
# 55  6.3  3.3  4.7  1.6  Iris-versicolor
# 56  4.9  2.4  3.3  1.0  Iris-versicolor
# 57  6.6  2.9  4.6  1.3  Iris-versicolor
# 58  5.2  2.7  3.9  1.4  Iris-versicolor
# 59  5.0  2.0  3.5  1.0  Iris-versicolor
# 60  5.9  3.0  4.2  1.5  Iris-versicolor
# 61  6.0  2.2  4.0  1.0  Iris-versicolor
# 62  6.1  2.9  4.7  1.4  Iris-versicolor
# 63  5.6  2.9  3.6  1.3  Iris-versicolor
# 64  6.7  3.1  4.4  1.4  Iris-versicolor
# 65  5.6  3.0  4.5  1.5  Iris-versicolor
# 66  5.8  2.7  4.1  1.0  Iris-versicolor
# 67  6.2  2.2  4.5  1.5  Iris-versicolor
# 68  5.6  2.5  3.9  1.1  Iris-versicolor
# 69  5.9  3.2  4.8  1.8  Iris-versicolor

# %%
df.max()
# Out:
# sl                        7.9
# sw                        4.4
# pl                        6.9
# pw                        2.5
# flower_type    Iris-virginica
# dtype: object

# %%
df.min()
# Out:
# sl                     4.3
# sw                     2.0
# pl                     1.0
# pw                     0.1
# flower_type    Iris-setosa
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sl           149 non-null    float64
#  1   sw           149 non-null    float64
#  2   pl           149 non-null    float64
#  3   pw           149 non-null    float64
#  4   flower_type  149 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %% [markdown]
# # Data Visualization

# %%
# Understanding using graphics

# %%
df['sl'].hist()
# Out:
# <AxesSubplot:>

# %%
df['sw'].hist()
# Out:
# <AxesSubplot:>

# %%
df['pl'].hist()
# Out:
# <AxesSubplot:>

# %%
df['pw'].hist()
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)

# %%
sns.pairplot(df, hue='flower_type')

# %%
# Get the columns
col = df.columns.drop(['flower_type'])
# creating x axis
x = range(0,df.shape[0])
# creating fig and axis
fig, ax = plt.subplots()
# ploting each column
for column in col:
    ax.plot(x, df[column], label=column)

ax.set_title('Iris Dataset')
ax.legend()

# %%
# Visualization using Different kind of categorical plot
sns.catplot(x = 'flower_type', y = 'sl', data = df, kind='strip')
sns.catplot(x = 'flower_type', y = 'sw', data = df, kind='box')
sns.catplot(x = 'flower_type', y = 'pl', data = df, kind='boxen')
sns.catplot(x = 'flower_type', y = 'pw', data = df, kind='violin')

# %%
# Heatmap is defined as a graphical representation of data using colors to visualize the value of the matrix
plt.figure(figsize=(10,7))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# # Splitting Dataset into the Trainging set and Test set

# %%
from sklearn.model_selection import train_test_split

X = df.drop(columns=['flower_type'])
y = df['flower_type']

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3, random_state = 1)

# %% [markdown]
# # Selecting Supervised Machine Learning Models

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
lr = LogisticRegression()
knn = KNeighborsClassifier()
svm = SVC()
nb = GaussianNB()
dt = DecisionTreeClassifier()
rf = RandomForestClassifier()

# %% [markdown]
# # Training And Evaluation

# %%
models = [lr,knn,svm,nb,dt,rf]
scores = []

for model in models:
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    scores.append(accuracy_score(y_test, y_pred))
    print("Accuracy of " + type(model).__name__ + ' is', accuracy_score(y_test,y_pred))
# Out:
# Accuracy of LogisticRegression is 0.9555555555555556
# Accuracy of KNeighborsClassifier is 0.9555555555555556
# Accuracy of SVC is 0.9555555555555556
# Accuracy of GaussianNB is 0.9333333333333333
# Accuracy of DecisionTreeClassifier is 0.9555555555555556
# Accuracy of RandomForestClassifier is 0.9555555555555556
# C:\Users\Omkar\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
results = pd.DataFrame({
    'Models':['Logistic Regression', 'K-Nearest Neighbors', 'Support Vector Machine', 'Naive Bayes', 'Decision Tree',
             'Random Forest'], 'Accuracy': scores})

results = results.sort_values(by='Accuracy', ascending=False)
print(results)
# Out:
#                    Models  Accuracy
# 0     Logistic Regression  0.955556
# 1     K-Nearest Neighbors  0.955556
# 2  Support Vector Machine  0.955556
# 4           Decision Tree  0.955556
# 5           Random Forest  0.955556
# 3             Naive Bayes  0.933333
